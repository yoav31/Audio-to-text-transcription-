# %%
# %pip install flask flask-cors
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ensorflow (c:\Users\yoav3\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (c:\Users\yoav3\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (c:\Users\yoav3\AppData\Local\Programs\Python\Python312\Lib\site-packages)
